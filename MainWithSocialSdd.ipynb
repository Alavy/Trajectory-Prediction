# %%
import tensorflow as tf
import numpy as np
import random
import glob
import pandas as pd
import pickle

# %%
#Params
kld_reg= 1
adl_reg=1

fdim=16
zdim=16
sigma=1.3
past_length=8
future_length=12
data_scale=1.86

enc_past_size=(past_length*2,512,256,fdim)
enc_dest_size=(2,8,16,fdim)

enc_latent_size=(2*fdim,8,50,2*zdim)
dec_size=(fdim + zdim,1024,512,1024,2)

predictor_size=(2*fdim + 2,1024,512,256,2*(future_length-1))

non_local_theta_size = (2*fdim + 2,256,128,64,128)
non_local_phi_size=(2*fdim + 2,256,128,64,128)
non_local_g_size=(2*fdim + 2,256,128,64,2*fdim + 2)
nonlocal_pools=3
learning_rate=0.0003

# %%
def loadData(file_path: str):
  npz = np.load(file_path, allow_pickle=True)
  return npz['observations'], npz['obs_speed'], npz['targets'], npz[
      'target_speed'], npz['mean'], npz['std']

# %%
class Dense(tf.Module):
  def __init__(self, input_dim, output_size, name=None):
    super(Dense, self).__init__(name=name)
    self.w = tf.Variable(tf.random.uniform([input_dim, output_size],-(1.0/input_dim)**0.5,(1.0/input_dim)**0.5 ),name='w',dtype=tf.float32,trainable=True)
    self.b = tf.Variable(tf.random.uniform([output_size],-(1.0/input_dim)**0.5,(1.0/input_dim)**0.5 ), name='b',dtype=tf.float32,trainable=True)
  def __call__(self, x):
    #x = tf.constant(x,dtype=tf.float32)
    y = tf.matmul(x, self.w) + self.b
    return y

class FullyConnectedNeuralNet(tf.Module):
  def __init__(self,sizes, name=None):
    super(FullyConnectedNeuralNet, self).__init__(name=name)
    self.layers = []
    with self.name_scope:
      for i in range(len(sizes)-1):
        self.layers.append(Dense(input_dim=sizes[i], output_size=sizes[i+1]))
  @tf.Module.with_name_scope
  def __call__(self, x):
    for i,layer in enumerate(self.layers):
        x=layer(x)
        if i != len(self.layers)-1:
            x = tf.nn.relu(x)
    return x

# %%
class MainModel(tf.Module):
    def __init__(self,name=None):
        super(MainModel, self).__init__(name=name)

        self.zdim = zdim
        self.sigma = sigma
        self.nonlocal_pools = nonlocal_pools
        


        self.pastEncoder = FullyConnectedNeuralNet(enc_past_size)

        self.destEncoder = FullyConnectedNeuralNet(enc_dest_size)

        self.latentDistributionEncoder = FullyConnectedNeuralNet(enc_latent_size)

        self.latentDistributionDecoder = FullyConnectedNeuralNet(dec_size)


        self.nonLocalTheta = FullyConnectedNeuralNet(non_local_theta_size)
        self.nonLocalPhi = FullyConnectedNeuralNet(non_local_phi_size)
        self.nonLocalG = FullyConnectedNeuralNet(non_local_g_size)
        
        self.predictorNetwork = FullyConnectedNeuralNet(predictor_size)

    def forward(self, x, initial_pos, dest=[], mask =[] ):

        if len(dest):
            self.training=True
        else:
            self.training=False
        
        # encode
        traj_past_ftr = self.pastEncoder(x)
        #print(f"ftraj max {ftraj.numpy().max()}")
        if not self.training:
            z = tf.random.normal((x.shape[0], self.zdim),0,self.sigma)

        else:
            dest_ftr = self.destEncoder(dest)
            #print(f"dest_features Max {dest_features.numpy().max()}")

            concat_ftr =tf.concat((traj_past_ftr, dest_ftr), axis = 1)
            latent =  self.latentDistributionEncoder(concat_ftr)
            mu = latent[:, 0:self.zdim] # 2-d array
            logvar =  latent[:, self.zdim:] # 2-d array

            var = tf.math.exp(logvar*0.5)
            #print(f"var {var}")
            eps = tf.random.normal(var.shape)
            z = eps*var + mu
            #print(f"z -> {z}")


        latentDistributionDecoder_input = tf.concat((traj_past_ftr, z), axis = 1)
        generated_dest = self.latentDistributionDecoder(latentDistributionDecoder_input)
        #generated_dest = tf.where(tf.math.is_nan(generated_dest), tf.zeros_like(generated_dest), generated_dest)

        if self.training:
            generated_dest_ftr = self.destEncoder(generated_dest)
            #generated_dest_ftr = tf.where(tf.math.is_nan(generated_dest_ftr), tf.zeros_like(generated_dest_ftr), generated_dest_ftr)
            #print(f"{ tf.math.reduce_any(tf.math.is_nan(generated_dest_ftr))}")

            prediction_ftr = tf.concat((traj_past_ftr, generated_dest_ftr,initial_pos), axis = 1)
            for i in range(self.nonlocal_pools):
                prediction_ftr = self.nonLocalSocialPooling(prediction_ftr, mask)
            pred_future = self.predictorNetwork(prediction_ftr)
        
            return generated_dest, mu, logvar, pred_future
        else:
            return generated_dest
    
    def nonLocalSocialPooling(self, feat, mask):
        # N,C
        theta_x = self.nonLocalTheta(feat)
        # C,N
        phi_x = tf.transpose(self.nonLocalPhi(feat))

        # f_ij = (theta_i)^T(phi_j), (N,N)
        f = tf.matmul(theta_x , phi_x)

        # f_weights_i =  exp(f_ij)/(\sum_{j=1}^N exp(f_ij))
        f_weights =tf.nn.softmax(f, axis = -1)
        # setting weights of non neighbours to zero
        f_weights = f_weights * mask
        pooled_g = self.nonLocalG(feat)
        
        #print(f"f_weights {f_weights.shape}")
        #print(f"self.pooled_g(feat) {pooled_g.shape}")
        
        # rescaling row weights to 1
        f_weights = tf.math.l2_normalize(f_weights,axis=1)
        #print(f"f_weights {f_weights.shape}")

        # ith row of all_pooled_f = \sum_{j=1}^N f_weights_i_j * g_row_j
        pooled_f = tf.matmul(f_weights, pooled_g)

        return pooled_f + feat

    def predict(self, past, generated_dest, mask, initial_pos):
        
        traj_past_ftr = self.pastEncoder(past)
        generated_dest_ftr = self.destEncoder(generated_dest)
        prediction_ftr = tf.concat((traj_past_ftr, generated_dest_ftr,initial_pos), axis = 1)
        for i in range(self.nonlocal_pools):
            prediction_ftr = self.nonLocalSocialPooling(prediction_ftr, mask)   
        future_traj = self.predictorNetwork(prediction_ftr)
        return future_traj

# %%
def calculate_loss(dest, dest_rec, mean, log_var, future, future_rec):
    
    rcl = tf.math.reduce_mean(tf.keras.metrics.mean_squared_error(dest, dest_rec))
    adl = tf.math.reduce_mean(tf.keras.metrics.mean_squared_error(future, future_rec))

    kld = -0.5 * tf.math.reduce_sum(1 + log_var - mean**2 - tf.math.exp(log_var))

    return rcl, kld, adl

# %%
def next_batch(X,batchSize):
    start = random.randint(0, len(X)-batchSize)
    return X[start:start+batchSize]

# %%
def train(model,optimizer):
    trajectory_batches,mask_batches,initial_pos_batches = loadDataSocial('./social_pool_data/train_all_512_0_100.pickle',set_name="train")
    
    train_loss = 0
    total_rcl, total_kld, total_adl = 0, 0, 0
    
    for i, (traj, mask, initial_pos) in enumerate(zip(trajectory_batches,mask_batches,initial_pos_batches)):
        traj -= traj[:, :1, :]
        traj *= data_scale
        x = traj[:, :past_length, :]
        y = traj[:, past_length:, :]

        x = x.reshape(-1, x.shape[1]*x.shape[2]) # (x,y,x,y ... )
        dest = y[:, -1, :]
        future = y[:, :-1, :].reshape(y.shape[0],-1)
        #x.astype(np.float64)
        #print(f"trajx-> {trajx.shape}")
        
        #print(f"X shape -> {x.shape}")
        #print(f"initial_pos -> {initial_pos.shape}")
        #print(f"dest shape -> {dest.shape}")
        #print(f"mask shape -> {mask.shape}")
         
        with tf.GradientTape() as tape:
            x=tf.constant(x,dtype=tf.float32)
            initial_pos=tf.constant(initial_pos,dtype=tf.float32)
            dest=tf.constant(dest,dtype=tf.float32)

            tape.watch(x)
            tape.watch(initial_pos)
            tape.watch(dest)

            dest_rec, mu, var, future_rec = model.forward(x, initial_pos, dest=dest, mask=mask)
            #print(f"dest_recon {dest_recon}")
            #print(f"mu {mu}")
            #print(f"var {var}")
            #print(f"interpolated_future {interpolated_future}") 
            rcl, kld, adl = calculate_loss(dest, dest_rec, mu, var, future, future_rec)   
            loss = rcl + kld * kld_reg + adl * adl_reg
            #print(f"loss -> {loss}")
        grad_sub = tape.gradient(loss, model.trainable_variables)
        optimizer.apply_gradients(zip(grad_sub, model.trainable_variables))
       
                    
        #print(f"total Loss {loss}")
        #print(f"rcl Loss {rcl}")
        #print(f"kld Loss {kld}")
        #print(f"adl Loss {adl}")
        train_loss+=loss
        total_rcl+=rcl
        total_kld+=kld
        total_adl+=adl
    return train_loss, total_rcl, total_kld, total_adl

# %%
def test(model, best_of_n = 1):
    trajectory_batches,mask_batches,initial_pos_batches = loadDataSocial('./social_pool_data/test_all_4096_0_100.pickle',set_name="test")
    for i, (traj, mask, initial_pos) in enumerate(zip(trajectory_batches,mask_batches,initial_pos_batches)):
   
        traj -= traj[:, :1, :]
        traj *= data_scale
        x = traj[:, :past_length,:]
        y = traj[:, past_length:,:]

        x = x.reshape(-1, x.shape[1]*x.shape[2])

        dest = y[:, -1, :]
    
        destination_errors = []
        dectination_recs = []
    
        for _ in range(best_of_n):
            x=tf.constant(x,dtype=tf.float32)
            initial_pos=tf.constant(initial_pos,dtype=tf.float32)
            dest_rec = model.forward(x, initial_pos)
            dectination_recs.append(np.array(dest_rec))

            error = np.linalg.norm(dest_rec - dest, axis = 1)
            destination_errors.append(error)

        destination_errors = np.array(destination_errors)
        dectination_recs = np.array(dectination_recs)
        # average error
        avg_dest_error = np.mean(destination_errors)

        indices = np.argmin(destination_errors, axis = 0)

        best_dest = dectination_recs[indices,np.arange(x.shape[0]),  :]

        # taking the minimum error out of all guess
        dest_error = np.mean(np.min(destination_errors, axis = 0))

        future_dest = model.predict(x, best_dest, mask, initial_pos)
        # final overall prediction
        predicted_future = np.concatenate((future_dest, best_dest), axis = 1)
        predicted_future = np.reshape(predicted_future, (-1, future_length, 2))
        # ADE error
        overall_error = np.mean(np.linalg.norm(y - predicted_future, axis = 2))

        overall_error /= data_scale
        dest_error /= data_scale
        avg_dest_error /= data_scale
        #print('Test time error in destination best: {:0.3f} and mean: {:0.3f}'.format(dest_error, avg_dest_error))
        #print('Test time error overall (ADE) best: {:0.3f}'.format(overall_error))

    return overall_error, dest_error, avg_dest_error

# %%
def run_train():
    epochs = 1000
    batchSize=100
    model=MainModel()
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    N=20
    best_test_loss = 50 # start saving after this threshold
    best_endpoint_loss = 50
    for epo in range(epochs):
        train_loss, rcl, kld, adl = train(model,optimizer)
        test_loss, final_point_loss_best, final_point_loss_avg = test(model, best_of_n = N)
                
        if best_test_loss > test_loss:
            print("Epoch: ", epo+1)
            print('################## BEST PERFORMANCE {:0.2f} ########'.format(test_loss))
            best_test_loss = test_loss
        

        if final_point_loss_best < best_endpoint_loss:
            best_endpoint_loss = final_point_loss_best

        print("Train Loss", train_loss)
        print("RCL", rcl)
        print("KLD", kld)
        print("ADL", adl)
        print("Test ADE", test_loss)
        print("Test Average FDE (Across  all samples)", final_point_loss_avg)
        print("Test Min FDE", final_point_loss_best)
        print("Test Best ADE Loss So Far (N = {})".format(N), best_test_loss)
        print("Test Best Min FDE (N = {})".format(N), best_endpoint_loss)

# %%
def loadDataSocial(load_name,set_name="train", id=False):
    
    with open(load_name, 'rb') as f:
        data = pickle.load(f)
    traj, masks = data
    traj_new = []

    if id==False:
        for t in traj:
            t = np.array(t)
            t = t[:,:,2:]
            traj_new.append(t)
            if set_name=="train":
            #augment training set with reversed tracklets...
                reverse_t = np.flip(t, axis=1).copy()
                traj_new.append(reverse_t)
    else:
        for t in traj:
            t = np.array(t)
            traj_new.append(t)
            if set_name=="train":
                #augment training set with reversed tracklets...
                reverse_t = np.flip(t, axis=1).copy()
                traj_new.append(reverse_t)
    masks_new = []
    
    for m in masks:
        masks_new.append(m)
        if set_name=="train":
            #add second time for the reversed tracklets...
            masks_new.append(m)

    traj_new = np.array(traj_new)
    masks_new = np.array(masks_new)
    trajectory_batches = traj_new.copy()
    mask_batches = masks_new.copy()
    
    initial_pos_batches = np.array(initial_pos(trajectory_batches)) # for relative positioning
    return trajectory_batches,mask_batches,initial_pos_batches

def initial_pos(traj_batches):
    batches = []
    for b in traj_batches:
        starting_pos = b[:,7,:].copy()/1000 #starting pos is end of past, start of future. scaled down.
        batches.append(starting_pos)
    return batches

# %%
run_train()
# Out:
# <ipython-input-1196-47f677a6bda1>:33: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   traj_new = np.array(traj_new)
# <ipython-input-1196-47f677a6bda1>:34: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   masks_new = np.array(masks_new)
# <ipython-input-1196-47f677a6bda1>:38: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   initial_pos_batches = np.array(initial_pos(trajectory_batches)) # for relative positioning
# Train Loss tf.Tensor(3376031.2, shape=(), dtype=float32)
# RCL tf.Tensor(2161432.5, shape=(), dtype=float32)
# KLD tf.Tensor(34106.88, shape=(), dtype=float32)
# ADL tf.Tensor(1180492.0, shape=(), dtype=float32)
# Test ADE 116.40176981676316
# Test Average FDE (Across  all samples) 163.70176910072243
# Test Min FDE 163.4874241326445
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2817523.0, shape=(), dtype=float32)
# RCL tf.Tensor(1942469.0, shape=(), dtype=float32)
# KLD tf.Tensor(5911.9414, shape=(), dtype=float32)
# ADL tf.Tensor(869142.56, shape=(), dtype=float32)
# Test ADE 104.80539569364748
# Test Average FDE (Across  all samples) 162.16952416204637
# Test Min FDE 161.95255402595765
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2777374.5, shape=(), dtype=float32)
# RCL tf.Tensor(1932778.1, shape=(), dtype=float32)
# KLD tf.Tensor(2462.7954, shape=(), dtype=float32)
# ADL tf.Tensor(842133.9, shape=(), dtype=float32)
# Test ADE 105.59913714628941
# Test Average FDE (Across  all samples) 163.23169995379703
# Test Min FDE 163.0117929109963
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2774258.5, shape=(), dtype=float32)
# RCL tf.Tensor(1927262.6, shape=(), dtype=float32)
# KLD tf.Tensor(1348.9135, shape=(), dtype=float32)
# ADL tf.Tensor(845647.1, shape=(), dtype=float32)
# Test ADE 106.63641966488622
# Test Average FDE (Across  all samples) 162.63409686344926
# Test Min FDE 162.3925321845598
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2764118.2, shape=(), dtype=float32)
# RCL tf.Tensor(1922154.8, shape=(), dtype=float32)
# KLD tf.Tensor(821.99365, shape=(), dtype=float32)
# ADL tf.Tensor(841141.0, shape=(), dtype=float32)
# Test ADE 105.83999657858375
# Test Average FDE (Across  all samples) 163.08810326360887
# Test Min FDE 162.84950830603157
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2757878.2, shape=(), dtype=float32)
# RCL tf.Tensor(1919720.0, shape=(), dtype=float32)
# KLD tf.Tensor(525.4078, shape=(), dtype=float32)
# ADL tf.Tensor(837632.44, shape=(), dtype=float32)
# Test ADE 106.00685337530565
# Test Average FDE (Across  all samples) 162.71929997269825
# Test Min FDE 162.48680853074595
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2758544.0, shape=(), dtype=float32)
# RCL tf.Tensor(1920159.2, shape=(), dtype=float32)
# KLD tf.Tensor(405.51904, shape=(), dtype=float32)
# ADL tf.Tensor(837979.75, shape=(), dtype=float32)
# Test ADE 106.24996524046077
# Test Average FDE (Across  all samples) 162.97715710055442
# Test Min FDE 162.70797893565188
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2756620.8, shape=(), dtype=float32)
# RCL tf.Tensor(1920729.8, shape=(), dtype=float32)
# KLD tf.Tensor(324.03983, shape=(), dtype=float32)
# ADL tf.Tensor(835567.1, shape=(), dtype=float32)
# Test ADE 106.08423146938384
# Test Average FDE (Across  all samples) 163.07855421496976
# Test Min FDE 162.8006145518313
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2757185.0, shape=(), dtype=float32)
# RCL tf.Tensor(1922692.2, shape=(), dtype=float32)
# KLD tf.Tensor(273.58594, shape=(), dtype=float32)
# ADL tf.Tensor(834219.44, shape=(), dtype=float32)
# Test ADE 105.71022816744676
# Test Average FDE (Across  all samples) 162.81334661668345
# Test Min FDE 162.52257644489245
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2756303.0, shape=(), dtype=float32)
# RCL tf.Tensor(1922997.0, shape=(), dtype=float32)
# KLD tf.Tensor(231.4505, shape=(), dtype=float32)
# ADL tf.Tensor(833074.7, shape=(), dtype=float32)
# Test ADE 105.59966434062876
# Test Average FDE (Across  all samples) 162.32732957409274
# Test Min FDE 162.0201192876344
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2754479.8, shape=(), dtype=float32)
# RCL tf.Tensor(1922782.0, shape=(), dtype=float32)
# KLD tf.Tensor(209.26564, shape=(), dtype=float32)
# ADL tf.Tensor(831488.6, shape=(), dtype=float32)
# Test ADE 105.2589698903922
# Test Average FDE (Across  all samples) 161.8050523983535
# Test Min FDE 161.4715083952873
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2753575.2, shape=(), dtype=float32)
# RCL tf.Tensor(1921952.4, shape=(), dtype=float32)
# KLD tf.Tensor(179.06723, shape=(), dtype=float32)
# ADL tf.Tensor(831443.56, shape=(), dtype=float32)
# Test ADE 104.37320727760222
# Test Average FDE (Across  all samples) 161.20603828019992
# Test Min FDE 160.86934407552081
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2743563.2, shape=(), dtype=float32)
# RCL tf.Tensor(1915039.8, shape=(), dtype=float32)
# KLD tf.Tensor(153.25986, shape=(), dtype=float32)
# ADL tf.Tensor(828370.1, shape=(), dtype=float32)
# Test ADE 103.89059484368748
# Test Average FDE (Across  all samples) 160.78461677797378
# Test Min FDE 160.42667511970765
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2738852.0, shape=(), dtype=float32)
# RCL tf.Tensor(1911753.0, shape=(), dtype=float32)
# KLD tf.Tensor(135.64821, shape=(), dtype=float32)
# ADL tf.Tensor(826963.25, shape=(), dtype=float32)
# Test ADE 104.0948375471289
# Test Average FDE (Across  all samples) 160.59481713079637
# Test Min FDE 160.21214967132894
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2734902.2, shape=(), dtype=float32)
# RCL tf.Tensor(1909695.5, shape=(), dtype=float32)
# KLD tf.Tensor(119.25898, shape=(), dtype=float32)
# ADL tf.Tensor(825087.4, shape=(), dtype=float32)
# Test ADE 103.91734646182165
# Test Average FDE (Across  all samples) 160.8324932795699
# Test Min FDE 160.45934205414144
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2733054.0, shape=(), dtype=float32)
# RCL tf.Tensor(1908310.4, shape=(), dtype=float32)
# KLD tf.Tensor(106.69505, shape=(), dtype=float32)
# ADL tf.Tensor(824637.3, shape=(), dtype=float32)
# Test ADE 103.84300153797912
# Test Average FDE (Across  all samples) 160.42603523500503
# Test Min FDE 160.03646030220932
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2729998.8, shape=(), dtype=float32)
# RCL tf.Tensor(1906583.1, shape=(), dtype=float32)
# KLD tf.Tensor(100.106476, shape=(), dtype=float32)
# ADL tf.Tensor(823315.9, shape=(), dtype=float32)
# Test ADE 103.8265608250385
# Test Average FDE (Across  all samples) 160.45048211210516
# Test Min FDE 160.0404800907258
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2726526.8, shape=(), dtype=float32)
# RCL tf.Tensor(1904152.2, shape=(), dtype=float32)
# KLD tf.Tensor(85.77047, shape=(), dtype=float32)
# ADL tf.Tensor(822288.25, shape=(), dtype=float32)
# Test ADE 103.6851254617342
# Test Average FDE (Across  all samples) 160.4810325048303
# Test Min FDE 160.08596112651207
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2725324.8, shape=(), dtype=float32)
# RCL tf.Tensor(1903423.4, shape=(), dtype=float32)
# KLD tf.Tensor(85.641396, shape=(), dtype=float32)
# ADL tf.Tensor(821816.0, shape=(), dtype=float32)
# Test ADE 103.941061121874
# Test Average FDE (Across  all samples) 160.46434628066194
# Test Min FDE 160.05434425928257
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2722253.0, shape=(), dtype=float32)
# RCL tf.Tensor(1901548.2, shape=(), dtype=float32)
# KLD tf.Tensor(82.20342, shape=(), dtype=float32)
# ADL tf.Tensor(820622.56, shape=(), dtype=float32)
# Test ADE 104.00400530549015
# Test Average FDE (Across  all samples) 160.43107227612566
# Test Min FDE 159.99836255145328
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2721463.8, shape=(), dtype=float32)
# RCL tf.Tensor(1900827.9, shape=(), dtype=float32)
# KLD tf.Tensor(79.86197, shape=(), dtype=float32)
# ADL tf.Tensor(820556.1, shape=(), dtype=float32)
# Test ADE 104.06463974028826
# Test Average FDE (Across  all samples) 160.36234209614415
# Test Min FDE 159.91286411080307
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2718949.5, shape=(), dtype=float32)
# RCL tf.Tensor(1898998.0, shape=(), dtype=float32)
# KLD tf.Tensor(80.58594, shape=(), dtype=float32)
# ADL tf.Tensor(819870.8, shape=(), dtype=float32)
# Test ADE 103.80255637462216
# Test Average FDE (Across  all samples) 160.3341051327285
# Test Min FDE 159.8699918357275
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2717305.5, shape=(), dtype=float32)
# RCL tf.Tensor(1898154.1, shape=(), dtype=float32)
# KLD tf.Tensor(82.37522, shape=(), dtype=float32)
# ADL tf.Tensor(819068.8, shape=(), dtype=float32)
# Test ADE 103.90530240800561
# Test Average FDE (Across  all samples) 160.5057911206317
# Test Min FDE 160.01518003402217
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2717067.5, shape=(), dtype=float32)
# RCL tf.Tensor(1898070.4, shape=(), dtype=float32)
# KLD tf.Tensor(86.39893, shape=(), dtype=float32)
# ADL tf.Tensor(818910.44, shape=(), dtype=float32)
# Test ADE 103.81579804292384
# Test Average FDE (Across  all samples) 160.5198521767893
# Test Min FDE 160.03091463478663
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2714944.5, shape=(), dtype=float32)
# RCL tf.Tensor(1897190.2, shape=(), dtype=float32)
# KLD tf.Tensor(89.27066, shape=(), dtype=float32)
# ADL tf.Tensor(817664.8, shape=(), dtype=float32)
# Test ADE 103.78043709325058
# Test Average FDE (Across  all samples) 160.40916853053594
# Test Min FDE 159.89772017284105
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2713614.2, shape=(), dtype=float32)
# RCL tf.Tensor(1896183.1, shape=(), dtype=float32)
# KLD tf.Tensor(92.51812, shape=(), dtype=float32)
# ADL tf.Tensor(817338.4, shape=(), dtype=float32)
# Test ADE 104.03301763459021
# Test Average FDE (Across  all samples) 160.63330865675402
# Test Min FDE 160.10125273017474
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2713643.8, shape=(), dtype=float32)
# RCL tf.Tensor(1896301.5, shape=(), dtype=float32)
# KLD tf.Tensor(93.35197, shape=(), dtype=float32)
# ADL tf.Tensor(817249.06, shape=(), dtype=float32)
# Test ADE 104.2123501867693
# Test Average FDE (Across  all samples) 160.5313701014365
# Test Min FDE 159.9672379032258
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2712333.2, shape=(), dtype=float32)
# RCL tf.Tensor(1895628.5, shape=(), dtype=float32)
# KLD tf.Tensor(100.20248, shape=(), dtype=float32)
# ADL tf.Tensor(816604.4, shape=(), dtype=float32)
# Test ADE 103.99624610034424
# Test Average FDE (Across  all samples) 160.68292433215726
# Test Min FDE 160.12535505397344
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2710967.5, shape=(), dtype=float32)
# RCL tf.Tensor(1895109.1, shape=(), dtype=float32)
# KLD tf.Tensor(105.9673, shape=(), dtype=float32)
# ADL tf.Tensor(815751.94, shape=(), dtype=float32)
# Test ADE 103.84361301065411
# Test Average FDE (Across  all samples) 160.91659709971438
# Test Min FDE 160.32831335580477
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2711061.5, shape=(), dtype=float32)
# RCL tf.Tensor(1895373.5, shape=(), dtype=float32)
# KLD tf.Tensor(121.74953, shape=(), dtype=float32)
# ADL tf.Tensor(815565.8, shape=(), dtype=float32)
# Test ADE 103.75329149471719
# Test Average FDE (Across  all samples) 160.58830343266968
# Test Min FDE 159.97762372416832
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2709860.2, shape=(), dtype=float32)
# RCL tf.Tensor(1893809.2, shape=(), dtype=float32)
# KLD tf.Tensor(121.11314, shape=(), dtype=float32)
# ADL tf.Tensor(815930.3, shape=(), dtype=float32)
# Test ADE 103.68611542885546
# Test Average FDE (Across  all samples) 160.614013671875
# Test Min FDE 159.99742733534944
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2709374.8, shape=(), dtype=float32)
# RCL tf.Tensor(1893613.8, shape=(), dtype=float32)
# KLD tf.Tensor(126.28298, shape=(), dtype=float32)
# ADL tf.Tensor(815634.06, shape=(), dtype=float32)
# Test ADE 103.71343102994132
# Test Average FDE (Across  all samples) 160.55575134933636
# Test Min FDE 159.93775398500503
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2708718.5, shape=(), dtype=float32)
# RCL tf.Tensor(1893072.4, shape=(), dtype=float32)
# KLD tf.Tensor(133.56241, shape=(), dtype=float32)
# ADL tf.Tensor(815511.94, shape=(), dtype=float32)
# Test ADE 103.6084221397883
# Test Average FDE (Across  all samples) 160.41427120085686
# Test Min FDE 159.76068640267977
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2707678.2, shape=(), dtype=float32)
# RCL tf.Tensor(1892477.9, shape=(), dtype=float32)
# KLD tf.Tensor(144.0139, shape=(), dtype=float32)
# ADL tf.Tensor(815056.4, shape=(), dtype=float32)
# Test ADE 103.54412582511792
# Test Average FDE (Across  all samples) 160.48370689474126
# Test Min FDE 159.8112372941868
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2706246.5, shape=(), dtype=float32)
# RCL tf.Tensor(1891291.4, shape=(), dtype=float32)
# KLD tf.Tensor(161.27625, shape=(), dtype=float32)
# ADL tf.Tensor(814794.44, shape=(), dtype=float32)
# Test ADE 103.55320861475569
# Test Average FDE (Across  all samples) 160.48697194745463
# Test Min FDE 159.78506765057963
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2705877.0, shape=(), dtype=float32)
# RCL tf.Tensor(1891324.2, shape=(), dtype=float32)
# KLD tf.Tensor(162.16286, shape=(), dtype=float32)
# ADL tf.Tensor(814390.9, shape=(), dtype=float32)
# Test ADE 103.59528554392678
# Test Average FDE (Across  all samples) 160.47881751932124
# Test Min FDE 159.75041543283768
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2705230.0, shape=(), dtype=float32)
# RCL tf.Tensor(1890753.1, shape=(), dtype=float32)
# KLD tf.Tensor(177.64459, shape=(), dtype=float32)
# ADL tf.Tensor(814298.9, shape=(), dtype=float32)
# Test ADE 103.64616732354364
# Test Average FDE (Across  all samples) 160.46078589654738
# Test Min FDE 159.69960202452955
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2704208.8, shape=(), dtype=float32)
# RCL tf.Tensor(1890214.1, shape=(), dtype=float32)
# KLD tf.Tensor(195.13321, shape=(), dtype=float32)
# ADL tf.Tensor(813799.56, shape=(), dtype=float32)
# Test ADE 103.60070853288585
# Test Average FDE (Across  all samples) 160.73444325436827
# Test Min FDE 159.9325692781838
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2704210.8, shape=(), dtype=float32)
# RCL tf.Tensor(1890078.6, shape=(), dtype=float32)
# KLD tf.Tensor(228.01418, shape=(), dtype=float32)
# ADL tf.Tensor(813904.94, shape=(), dtype=float32)
# Test ADE 103.7175622632693
# Test Average FDE (Across  all samples) 160.57046869749664
# Test Min FDE 159.7567158360635
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2703027.5, shape=(), dtype=float32)
# RCL tf.Tensor(1889370.4, shape=(), dtype=float32)
# KLD tf.Tensor(231.13014, shape=(), dtype=float32)
# ADL tf.Tensor(813425.7, shape=(), dtype=float32)
# Test ADE 103.58367285720222
# Test Average FDE (Across  all samples) 160.4124335832493
# Test Min FDE 159.56954135689682
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2703225.5, shape=(), dtype=float32)
# RCL tf.Tensor(1889497.1, shape=(), dtype=float32)
# KLD tf.Tensor(261.335, shape=(), dtype=float32)
# ADL tf.Tensor(813466.44, shape=(), dtype=float32)
# Test ADE 103.72687616807943
# Test Average FDE (Across  all samples) 160.6959025065104
# Test Min FDE 159.79320567141295
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2702517.0, shape=(), dtype=float32)
# RCL tf.Tensor(1889341.0, shape=(), dtype=float32)
# KLD tf.Tensor(280.92853, shape=(), dtype=float32)
# ADL tf.Tensor(812895.2, shape=(), dtype=float32)
# Test ADE 103.65275627311283
# Test Average FDE (Across  all samples) 160.47044979628694
# Test Min FDE 159.57341347971268
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2702154.0, shape=(), dtype=float32)
# RCL tf.Tensor(1888911.6, shape=(), dtype=float32)
# KLD tf.Tensor(314.16614, shape=(), dtype=float32)
# ADL tf.Tensor(812928.6, shape=(), dtype=float32)
# Test ADE 103.72066217253715
# Test Average FDE (Across  all samples) 160.5959984564012
# Test Min FDE 159.63646673387095
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2700871.2, shape=(), dtype=float32)
# RCL tf.Tensor(1888022.9, shape=(), dtype=float32)
# KLD tf.Tensor(332.88275, shape=(), dtype=float32)
# ADL tf.Tensor(812515.2, shape=(), dtype=float32)
# Test ADE 103.63827606875196
# Test Average FDE (Across  all samples) 160.5100898332493
# Test Min FDE 159.52156641150032
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2700824.0, shape=(), dtype=float32)
# RCL tf.Tensor(1887924.6, shape=(), dtype=float32)
# KLD tf.Tensor(360.8471, shape=(), dtype=float32)
# ADL tf.Tensor(812538.7, shape=(), dtype=float32)
# Test ADE 103.70969144791596
# Test Average FDE (Across  all samples) 160.63135618804603
# Test Min FDE 159.61344729187667
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2700185.2, shape=(), dtype=float32)
# RCL tf.Tensor(1887401.1, shape=(), dtype=float32)
# KLD tf.Tensor(403.25894, shape=(), dtype=float32)
# ADL tf.Tensor(812380.94, shape=(), dtype=float32)
# Test ADE 103.65031261357142
# Test Average FDE (Across  all samples) 160.56252756426412
# Test Min FDE 159.50934297295026
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2700203.5, shape=(), dtype=float32)
# RCL tf.Tensor(1887741.1, shape=(), dtype=float32)
# KLD tf.Tensor(441.80377, shape=(), dtype=float32)
# ADL tf.Tensor(812020.3, shape=(), dtype=float32)
# Test ADE 103.6877490947125
# Test Average FDE (Across  all samples) 160.7390865202873
# Test Min FDE 159.63101951024865
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2698824.5, shape=(), dtype=float32)
# RCL tf.Tensor(1886723.9, shape=(), dtype=float32)
# KLD tf.Tensor(479.91785, shape=(), dtype=float32)
# ADL tf.Tensor(811620.6, shape=(), dtype=float32)
# Test ADE 103.50633498808459
# Test Average FDE (Across  all samples) 160.53414293514783
# Test Min FDE 159.37445855909777
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2698417.0, shape=(), dtype=float32)
# RCL tf.Tensor(1886449.2, shape=(), dtype=float32)
# KLD tf.Tensor(521.74603, shape=(), dtype=float32)
# ADL tf.Tensor(811446.1, shape=(), dtype=float32)
# Test ADE 103.76450374555782
# Test Average FDE (Across  all samples) 160.70997996996806
# Test Min FDE 159.45680679813506
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2698159.2, shape=(), dtype=float32)
# RCL tf.Tensor(1886256.4, shape=(), dtype=float32)
# KLD tf.Tensor(588.83984, shape=(), dtype=float32)
# ADL tf.Tensor(811314.44, shape=(), dtype=float32)
# Test ADE 103.56426650443231
# Test Average FDE (Across  all samples) 160.6083531533518
# Test Min FDE 159.32165986748151
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2697474.5, shape=(), dtype=float32)
# RCL tf.Tensor(1885705.0, shape=(), dtype=float32)
# KLD tf.Tensor(645.53, shape=(), dtype=float32)
# ADL tf.Tensor(811123.9, shape=(), dtype=float32)
# Test ADE 103.71900336708676
# Test Average FDE (Across  all samples) 160.56321667086692
# Test Min FDE 159.20216550109205
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2697127.5, shape=(), dtype=float32)
# RCL tf.Tensor(1885178.8, shape=(), dtype=float32)
# KLD tf.Tensor(704.0471, shape=(), dtype=float32)
# ADL tf.Tensor(811244.7, shape=(), dtype=float32)
# Test ADE 103.63469532557589
# Test Average FDE (Across  all samples) 160.76942361811155
# Test Min FDE 159.3466317781838
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2696797.2, shape=(), dtype=float32)
# RCL tf.Tensor(1885096.0, shape=(), dtype=float32)
# KLD tf.Tensor(775.7952, shape=(), dtype=float32)
# ADL tf.Tensor(810925.75, shape=(), dtype=float32)
# Test ADE 103.75204118225463
# Test Average FDE (Across  all samples) 160.62013359480005
# Test Min FDE 159.14419850995463
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2695967.2, shape=(), dtype=float32)
# RCL tf.Tensor(1884266.9, shape=(), dtype=float32)
# KLD tf.Tensor(854.4879, shape=(), dtype=float32)
# ADL tf.Tensor(810846.2, shape=(), dtype=float32)
# Test ADE 103.81310542891009
# Test Average FDE (Across  all samples) 160.6591337470598
# Test Min FDE 159.10608435189852
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2695757.2, shape=(), dtype=float32)
# RCL tf.Tensor(1884286.5, shape=(), dtype=float32)
# KLD tf.Tensor(942.3157, shape=(), dtype=float32)
# ADL tf.Tensor(810527.94, shape=(), dtype=float32)
# Test ADE 103.84950934203019
# Test Average FDE (Across  all samples) 160.6786912487399
# Test Min FDE 159.06309722572243
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2695247.8, shape=(), dtype=float32)
# RCL tf.Tensor(1883614.4, shape=(), dtype=float32)
# KLD tf.Tensor(1055.3965, shape=(), dtype=float32)
# ADL tf.Tensor(810578.3, shape=(), dtype=float32)
# Test ADE 103.72780546924638
# Test Average FDE (Across  all samples) 160.67736225743448
# Test Min FDE 158.96872243573588
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2694772.8, shape=(), dtype=float32)
# RCL tf.Tensor(1883261.2, shape=(), dtype=float32)
# KLD tf.Tensor(1151.1125, shape=(), dtype=float32)
# ADL tf.Tensor(810360.0, shape=(), dtype=float32)
# Test ADE 103.8802996610033
# Test Average FDE (Across  all samples) 160.64461328650032
# Test Min FDE 158.84942495694725
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2694758.2, shape=(), dtype=float32)
# RCL tf.Tensor(1882842.0, shape=(), dtype=float32)
# KLD tf.Tensor(1359.3934, shape=(), dtype=float32)
# ADL tf.Tensor(810556.9, shape=(), dtype=float32)
# Test ADE 103.92089429579892
# Test Average FDE (Across  all samples) 160.80038419333837
# Test Min FDE 158.919188796833
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2693594.0, shape=(), dtype=float32)
# RCL tf.Tensor(1881660.0, shape=(), dtype=float32)
# KLD tf.Tensor(1486.0696, shape=(), dtype=float32)
# ADL tf.Tensor(810448.1, shape=(), dtype=float32)
# Test ADE 103.87429141233119
# Test Average FDE (Across  all samples) 160.47553605930779
# Test Min FDE 158.5364557081653
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2692688.0, shape=(), dtype=float32)
# RCL tf.Tensor(1880455.8, shape=(), dtype=float32)
# KLD tf.Tensor(1673.4889, shape=(), dtype=float32)
# ADL tf.Tensor(810558.6, shape=(), dtype=float32)
# Test ADE 103.92204435986751
# Test Average FDE (Across  all samples) 160.65860871345765
# Test Min FDE 158.58237974105342
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2692554.2, shape=(), dtype=float32)
# RCL tf.Tensor(1879850.2, shape=(), dtype=float32)
# KLD tf.Tensor(1975.4183, shape=(), dtype=float32)
# ADL tf.Tensor(810728.75, shape=(), dtype=float32)
# Test ADE 103.93781916419444
# Test Average FDE (Across  all samples) 160.77093308971774
# Test Min FDE 158.47105621009743
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2690932.5, shape=(), dtype=float32)
# RCL tf.Tensor(1877968.2, shape=(), dtype=float32)
# KLD tf.Tensor(2400.8809, shape=(), dtype=float32)
# ADL tf.Tensor(810563.4, shape=(), dtype=float32)
# Test ADE 104.16459832068574
# Test Average FDE (Across  all samples) 160.62159384450604
# Test Min FDE 158.1923618111559
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2688682.0, shape=(), dtype=float32)
# RCL tf.Tensor(1875799.9, shape=(), dtype=float32)
# KLD tf.Tensor(2864.235, shape=(), dtype=float32)
# ADL tf.Tensor(810017.75, shape=(), dtype=float32)
# Test ADE 104.14444696760812
# Test Average FDE (Across  all samples) 160.53432341544857
# Test Min FDE 157.9133556735131
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2686563.0, shape=(), dtype=float32)
# RCL tf.Tensor(1873063.6, shape=(), dtype=float32)
# KLD tf.Tensor(3752.9827, shape=(), dtype=float32)
# ADL tf.Tensor(809746.44, shape=(), dtype=float32)
# Test ADE 103.83143191307587
# Test Average FDE (Across  all samples) 160.302488265499
# Test Min FDE 157.45987430695564
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2684175.8, shape=(), dtype=float32)
# RCL tf.Tensor(1869566.2, shape=(), dtype=float32)
# KLD tf.Tensor(4909.2207, shape=(), dtype=float32)
# ADL tf.Tensor(809700.56, shape=(), dtype=float32)
# Test ADE 103.50442190021366
# Test Average FDE (Across  all samples) 160.19205072874664
# Test Min FDE 157.08250640540993
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2679565.8, shape=(), dtype=float32)
# RCL tf.Tensor(1864760.6, shape=(), dtype=float32)
# KLD tf.Tensor(6611.816, shape=(), dtype=float32)
# ADL tf.Tensor(808193.2, shape=(), dtype=float32)
# Test ADE 102.68251912954483
# Test Average FDE (Across  all samples) 160.47825967111893
# Test Min FDE 156.88699701780914
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2675381.5, shape=(), dtype=float32)
# RCL tf.Tensor(1859828.5, shape=(), dtype=float32)
# KLD tf.Tensor(9199.463, shape=(), dtype=float32)
# ADL tf.Tensor(806353.6, shape=(), dtype=float32)
# Test ADE 102.14639168578566
# Test Average FDE (Across  all samples) 160.94173308341732
# Test Min FDE 156.6705355080225
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2671600.2, shape=(), dtype=float32)
# RCL tf.Tensor(1856631.6, shape=(), dtype=float32)
# KLD tf.Tensor(10651.945, shape=(), dtype=float32)
# ADL tf.Tensor(804315.9, shape=(), dtype=float32)
# Test ADE 101.78207664334882
# Test Average FDE (Across  all samples) 161.24064127604166
# Test Min FDE 156.56513501239078
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2670953.5, shape=(), dtype=float32)
# RCL tf.Tensor(1855278.8, shape=(), dtype=float32)
# KLD tf.Tensor(11370.874, shape=(), dtype=float32)
# ADL tf.Tensor(804303.9, shape=(), dtype=float32)
# Test ADE 101.79664980023895
# Test Average FDE (Across  all samples) 161.12569173177081
# Test Min FDE 156.62682646064349
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2668178.2, shape=(), dtype=float32)
# RCL tf.Tensor(1853604.8, shape=(), dtype=float32)
# KLD tf.Tensor(11584.895, shape=(), dtype=float32)
# ADL tf.Tensor(802988.4, shape=(), dtype=float32)
# Test ADE 101.83784514604933
# Test Average FDE (Across  all samples) 161.25060050718244
# Test Min FDE 156.5587689799647
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2667265.5, shape=(), dtype=float32)
# RCL tf.Tensor(1852868.4, shape=(), dtype=float32)
# KLD tf.Tensor(11958.572, shape=(), dtype=float32)
# ADL tf.Tensor(802438.5, shape=(), dtype=float32)
# Test ADE 101.76373826373649
# Test Average FDE (Across  all samples) 161.2219041393649
# Test Min FDE 156.6998553532426
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2666886.2, shape=(), dtype=float32)
# RCL tf.Tensor(1852973.8, shape=(), dtype=float32)
# KLD tf.Tensor(11913.06, shape=(), dtype=float32)
# ADL tf.Tensor(801999.75, shape=(), dtype=float32)
# Test ADE 101.75191036383286
# Test Average FDE (Across  all samples) 161.08897219422042
# Test Min FDE 156.69222595871136
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2665203.2, shape=(), dtype=float32)
# RCL tf.Tensor(1851699.2, shape=(), dtype=float32)
# KLD tf.Tensor(11898.502, shape=(), dtype=float32)
# ADL tf.Tensor(801605.7, shape=(), dtype=float32)
# Test ADE 101.70263407986022
# Test Average FDE (Across  all samples) 161.01840439663138
# Test Min FDE 156.60717051516295
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2664311.2, shape=(), dtype=float32)
# RCL tf.Tensor(1850902.5, shape=(), dtype=float32)
# KLD tf.Tensor(11905.495, shape=(), dtype=float32)
# ADL tf.Tensor(801503.0, shape=(), dtype=float32)
# Test ADE 101.7178807090235
# Test Average FDE (Across  all samples) 161.1189975533434
# Test Min FDE 156.61502961189515
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2665626.2, shape=(), dtype=float32)
# RCL tf.Tensor(1851866.9, shape=(), dtype=float32)
# KLD tf.Tensor(11904.046, shape=(), dtype=float32)
# ADL tf.Tensor(801855.44, shape=(), dtype=float32)
# Test ADE 101.73023277795916
# Test Average FDE (Across  all samples) 161.02472120715726
# Test Min FDE 156.60927064957156
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2663932.8, shape=(), dtype=float32)
# RCL tf.Tensor(1850588.0, shape=(), dtype=float32)
# KLD tf.Tensor(11903.397, shape=(), dtype=float32)
# ADL tf.Tensor(801441.3, shape=(), dtype=float32)
# Test ADE 101.80269487377691
# Test Average FDE (Across  all samples) 160.97469534925236
# Test Min FDE 156.65432509555612
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2662789.5, shape=(), dtype=float32)
# RCL tf.Tensor(1850300.4, shape=(), dtype=float32)
# KLD tf.Tensor(11603.23, shape=(), dtype=float32)
# ADL tf.Tensor(800886.5, shape=(), dtype=float32)
# Test ADE 101.81690385884897
# Test Average FDE (Across  all samples) 160.92996904926915
# Test Min FDE 156.67178246282762
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2663264.2, shape=(), dtype=float32)
# RCL tf.Tensor(1850380.1, shape=(), dtype=float32)
# KLD tf.Tensor(11769.471, shape=(), dtype=float32)
# ADL tf.Tensor(801114.6, shape=(), dtype=float32)
# Test ADE 101.78410815033739
# Test Average FDE (Across  all samples) 160.82501155073925
# Test Min FDE 156.7741968298471
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2662432.8, shape=(), dtype=float32)
# RCL tf.Tensor(1849800.1, shape=(), dtype=float32)
# KLD tf.Tensor(11704.186, shape=(), dtype=float32)
# ADL tf.Tensor(800928.9, shape=(), dtype=float32)
# Test ADE 101.83275410142721
# Test Average FDE (Across  all samples) 160.82481466313843
# Test Min FDE 156.73383487168178
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2662108.2, shape=(), dtype=float32)
# RCL tf.Tensor(1849884.0, shape=(), dtype=float32)
# KLD tf.Tensor(11443.275, shape=(), dtype=float32)
# ADL tf.Tensor(800780.9, shape=(), dtype=float32)
# Test ADE 101.80962431769346
# Test Average FDE (Across  all samples) 160.75557585685482
# Test Min FDE 156.61711333900368
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2661688.0, shape=(), dtype=float32)
# RCL tf.Tensor(1849774.5, shape=(), dtype=float32)
# KLD tf.Tensor(11248.748, shape=(), dtype=float32)
# ADL tf.Tensor(800664.94, shape=(), dtype=float32)
# Test ADE 101.78781495671633
# Test Average FDE (Across  all samples) 160.79400175361224
# Test Min FDE 156.78504205519152
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2662184.0, shape=(), dtype=float32)
# RCL tf.Tensor(1850077.9, shape=(), dtype=float32)
# KLD tf.Tensor(11446.53, shape=(), dtype=float32)
# ADL tf.Tensor(800659.0, shape=(), dtype=float32)
# Test ADE 101.80946289558402
# Test Average FDE (Across  all samples) 160.64676264280914
# Test Min FDE 156.80773335118448
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
# Train Loss tf.Tensor(2660648.5, shape=(), dtype=float32)
# RCL tf.Tensor(1848945.5, shape=(), dtype=float32)
# KLD tf.Tensor(11606.193, shape=(), dtype=float32)
# ADL tf.Tensor(800096.8, shape=(), dtype=float32)
# Test ADE 101.8239020757461
# Test Average FDE (Across  all samples) 160.8523461126512
# Test Min FDE 156.78148167107693
# Test Best ADE Loss So Far (N = 20) 50
# Test Best Min FDE (N = 20) 50
